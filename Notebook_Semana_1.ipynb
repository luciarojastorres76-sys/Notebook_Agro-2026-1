# %% [markdown]
# <a href="https://colab.research.google.com/github/luciarojastorres76-sys/Notebook_Agro-2026-1/blob/main/Notebook_Semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 ancho = 1
 alto = 2

 ln= 2 * (ancho + alto)*3.25
 av=2 * (ancho * alto)

 print(ln)
 print(av)
# Out:
# 19.5
# 4
